# %%
lst = [1,2,3,4,5,6,7,8]
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [4, 5, 6, 7, 8, 1, 2]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [7, 8, 1, 2, 4, 5]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [2, 4, 5, 7, 8]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [7, 8, 2, 4]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [4, 7, 8]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [4, 7]

# %%
lst = lst[3:]+(lst[:3-1])
print(lst)
# Out:
# [4, 7]

# %%
lst = [1, 2, 3, 4, 5]

for _ in range(4):
   k = 6
   if k - 1 > len(lst):
        while k - 1 >= len(lst):
            k -= len(lst)
   del lst[k-1]
        

print(lst)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 8
#       4    k = 6
#       5    if k - 1 > len(lst):
#       6         while k - 1 >= len(lst):
#       7             k -= len(lst)
# ----> 8    del lst[k-1]
#       9
#      10
#      11 print(lst)
#
# IndexError: list assignment index out of range
