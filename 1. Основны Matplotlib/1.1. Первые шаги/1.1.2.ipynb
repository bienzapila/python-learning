# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,10])
plt.show()

# %%
x = [2, 1, 4, 3, 5]
y = [2, 4, 6 ,8 ,10]
plt.plot(x, y)
plt.show()

# %%
x1 = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
x2 = [1, 2, 3, 4]
y2 = [2, 3, 5, 8]
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
days = ['01.03', '03.03', '05.03', '07.03', '09.03',
        '11.03', '13.03', '15.03', '17.03', '19.03',
        '21.03', '23.03', '25.03', '27.03', '29.03']

shop_1 = [124, 131, 127, 135, 142,
          138, 145, 141, 149, 153,
          147, 155, 151, 158, 152]

shop_2 = [128, 125, 133, 129, 138,
          140, 135, 144, 146, 142,
          150, 148, 154, 149, 155]

plt.plot(days, shop_1, shop_2)
plt.show()
